# %%
# !pip install squarify
# Out:
# Requirement already satisfied: squarify in /usr/local/lib/python3.10/dist-packages (0.4.3)

# %%
import squarify
import matplotlib.pyplot as plt
import pandas as pd

# %%
sizes = [50, 25, 12, 6]
squarify.plot(sizes)
plt.show()

# %%
sizes=[50, 25, 12, 6]
label=["InfoStat", "Computer", "HCI", "DataScience"]
squarify.plot(sizes=sizes, label=label, alpha=0.6 )
plt.axis('off')
plt.show()

# %%
sizes=[50, 25, 12, 6]
label=["InfoStat", "Computer", "HCI", "DataScience"]
color=['red','blue','green','grey']
squarify.plot(sizes=sizes, label=label, color=color, alpha=0.6 )
plt.axis('off')
plt.show()

# %%
url = "https://s3-eu-west-1.amazonaws.com/data.defra.gov.uk/AnimalWelfare/animal-population-by-breed-on_1-march-2010.csv"
df = pd.read_csv(url)
df['Number of Animals'] = pd.to_numeric(df['Number of Animals'], errors='coerce')
df.dropna(inplace=True)
df.head()
# Out:
#               Breed  Number of Animals
# 0    ABERDEEN ANGUS           147047.0
# 1  ABERDEEN ANGUS X           516932.0
# 2    ANGLER ROTVIEH               38.0
# 3  ANGLER ROTVIEH X               38.0
# 4            ANKOLE               10.0

# %%
print(df)
# Out:
#                    Breed  Number of Animals
# 0         ABERDEEN ANGUS           147047.0
# 1       ABERDEEN ANGUS X           516932.0
# 2         ANGLER ROTVIEH               38.0
# 3       ANGLER ROTVIEH X               38.0
# 4                 ANKOLE               10.0
# ..                   ...                ...
# 217         WHITE PARK X              510.0
# 218   WHITEBRED S/HORN X             5913.0
# 219  WHITEBRED SHORTHORN              789.0
# 220                  YAK               16.0
# 221                 ZEBU               63.0
#
# [222 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, figsize = (12,12))
squarify.plot(sizes=df['Number of Animals'],
              label=df['Breed'],
              alpha=.8 )
plt.axis('off')
plt.show()

# %%
df.sort_values('Number of Animals', ascending=False, inplace=True)
fig, ax = plt.subplots(1, figsize = (12,12))
squarify.plot(sizes=df['Number of Animals'][:30],
              label=df['Breed'][:30],
              alpha=.8 )
plt.axis('off')

plt.show()
