# %% [markdown]
# ###문제4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/drive/MyDrive/MyLecture/2023/2학기/데이터처리프로그래밍/10-2주차/04_data2.csv')
PetalLength = data['PetalLength']
PetalWidth = data['PetalWidth']
SepalLength = data['SepalLength']
SepalWidth = data['SepalWidth']

# %% [markdown]
# ###문제5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/drive/MyDrive/MyLecture/2023/2학기/데이터처리프로그래밍/10-2주차/04_data2.csv')
PetalLength = data['PetalLength'].mean()
PetalWidth = data['PetalWidth'].mean()
SepalLength = data['SepalLength'].mean()
SepalWidth = data['SepalWidth'].mean()

# %% [markdown]
# ###문제6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/drive/MyDrive/MyLecture/2023/2학기/데이터처리프로그래밍/10-2주차/04_data2.csv')
SepalLength = data['SepalLength']
SepalWidth = data['SepalWidth']

# %% [markdown]
# ###문제7

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/MyDrive/MyLecture/2023/2학기/데이터처리프로그래밍/10-2주차/04_data2.csv')

# %% [markdown]
# ###문제8

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/MyDrive/MyLecture/2023/2학기/데이터처리프로그래밍/10-2주차/04_data2.csv')
